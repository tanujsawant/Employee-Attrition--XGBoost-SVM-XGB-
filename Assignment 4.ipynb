# %% [markdown]
# The motivation behind this assignment is to address a well known problem of attrition which is a huge problem in the Industry. Maintaining the attrition rate is pivotial for the industry. More and More companies are investing in Human Resource attrition to keep a tap on the attrition rate.
# We are feature construting the variable which are most pivotial for predicting attrition.

# %%
import pandas as pd #importing the pandas package

# %%
import numpy as np #importing the numpy package

# %%
import matplotlib.pyplot as plt #importing the matplotlib package

# %%
import seaborn as sb #importing the seaborn package

# %%
# %matplotlib inline

# %%
data = pd.read_csv("C:\\Users\\tanuj\\Desktop\\Subjects\\DSP\\Assignment4\\Employee_Attrition.csv") #reading the dataset

# %%
data.head() #Having a glimpse at dataset
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#            ...           RelationshipSatisfaction StandardHours  \
# ...

# %%
data.describe() #Describing the dataset
# Out:
#                Age    DailyRate  DistanceFromHome    Education  EmployeeCount  \
# count  1470.000000  1470.000000       1470.000000  1470.000000         1470.0
# mean     36.923810   802.485714          9.192517     2.912925            1.0
# std       9.135373   403.509100          8.106864     1.024165            0.0
# min      18.000000   102.000000          1.000000     1.000000            1.0
# 25%      30.000000   465.000000          2.000000     2.000000            1.0
# 50%      36.000000   802.000000          7.000000     3.000000            1.0
# 75%      43.000000  1157.000000         14.000000     4.000000            1.0
# max      60.000000  1499.000000         29.000000     5.000000            1.0
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     1470.000000              1470.000000  1470.000000     1470.000000
# mean      1024.865306                 2.721769    65.891156        2.729932
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
# Age                         1470 non-null int64
# Attrition                   1470 non-null object
# BusinessTravel              1470 non-null object
# DailyRate                   1470 non-null int64
# Department                  1470 non-null object
# DistanceFromHome            1470 non-null int64
# Education                   1470 non-null int64
# EducationField              1470 non-null object
# EmployeeCount               1470 non-null int64
# EmployeeNumber              1470 non-null int64
# EnvironmentSatisfaction     1470 non-null int64
# Gender                      1470 non-null object
# HourlyRate                  1470 non-null int64
# JobInvolvement              1470 non-null int64
# JobLevel                    1470 non-null int64
# JobRole                     1470 non-null object
# JobSatisfaction             1470 non-null int64
# ...

# %%
# Dropping Employee count as all values are 1 and hence attrition is independent of this feature
data = data.drop(['EmployeeCount'], axis=1)

# Dropping Employee Number since it is merely an identifier
data = data.drop(['EmployeeNumber'], axis=1)

# %%
corr = data.corr()
plt.figure(figsize = (10,5))
sb.heatmap(corr,cmap="PiYG",
          xticklabels=corr.columns.values,
          yticklabels=corr.columns.values)

# %%
sb.distplot(data.MonthlyIncome[data.Gender == 'Male'], bins = np.linspace(0,20000,60))
sb.distplot(data.MonthlyIncome[data.Gender == 'Female'], bins = np.linspace(0,20000,60))
plt.legend(['Male','Female'])
plt.show()
#Distribution of the male and female categories

# %%
plt.figure(figsize=(14,10))
plt.xticks(rotation=90)
sb.boxplot(x='Age', y='Attrition', data=data)

# %%
numerical = [u'Age', u'DailyRate', u'MonthlyIncome', u'YearsAtCompany', u'Attrition_numerical']
sb.set(style="ticks", color_codes=True)

g = sb.pairplot(data[numerical], hue='Attrition_numerical', kind="reg")
g.set(xticklabels=[])
sb.plt.show()

# %%
# Converting target variables from string to numerical values
target_map = {'Yes': 1, 'No': 0}
data["Attrition_numerical"] = data["Attrition"].apply(lambda x: target_map[x])
target = data["Attrition_numerical"]

# %%
numerical_columns  = [u'Age', u'DailyRate', u'DistanceFromHome', u'Education', u'EnvironmentSatisfaction',
             u'HourlyRate', u'JobInvolvement', u'JobLevel', u'JobSatisfaction',
             u'MonthlyIncome', u'MonthlyRate', u'NumCompaniesWorked',
             u'PercentSalaryHike', u'PerformanceRating', u'RelationshipSatisfaction',
             u'StockOptionLevel', u'TotalWorkingYears',
             u'TrainingTimesLastYear', u'WorkLifeBalance', u'YearsAtCompany',
             u'YearsInCurrentRole', u'YearsSinceLastPromotion',
             u'YearsWithCurrManager']

# %%
# Creating dummy columns for each categorical feature
categorical = []
for col, value in data.iteritems():
    if value.dtype == 'object':
        categorical.append(col)

# %%
# Store the numerical columns in a list numerical
numericalColumns = data.columns.difference(categorical)
attritionCategorical = data[categorical]
attritionCategorical = data.drop(['Attrition'], axis=1)
attritionCategorical = pd.get_dummies(attritionCategorical)
attritionNumerical = data[numerical_columns]
attritionFinal = pd.concat([attritionNumerical, attritionCategorical], axis=1)

# %%
attritionFinal.head()
# Out:
#    Age  DailyRate  DistanceFromHome  Education  EnvironmentSatisfaction  \
# 0   41       1102                 1          2                        2
# 1   49        279                 8          1                        3
# 2   37       1373                 2          2                        4
# 3   33       1392                 3          4                        4
# 4   27        591                 2          1                        1
#
#    HourlyRate  JobInvolvement  JobLevel  JobSatisfaction  MonthlyIncome  \
# 0          94               3         2                4           5993
# 1          61               2         2                2           5130
# 2          92               2         1                3           2090
# 3          56               3         1                3           2909
# 4          40               3         1                2           3468
#
#        ...       JobRole_Research Director  JobRole_Research Scientist  \
# ...

# %%
select_cols = ["Age","DailyRate","DistanceFromHome","Education","EnvironmentSatisfaction","PercentSalaryHike","PerformanceRating"]

# %%
x = attritionFinal[select_cols] #appending the columns to the dataset

# %%
y= data.Attrition #Defining our Y variable which is data

# %%
from sklearn.model_selection import train_test_split  #Importing the train and test function

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.3,random_state=36,stratify=y)

# %% [markdown]
# SUPPORT VECTOR MACHINE

# %%
from sklearn import svm

# %%
clf = svm.SVC()

# %%
clf.fit(x_train,y_train)
# Out:
# SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto', kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)

# %%
y_predict = clf.predict(x_test)

# %%
from sklearn.metrics import confusion_matrix,classification_report,accuracy_score

# %%
cm = confusion_matrix(y_test,y_pred)#creating the confusion matrix

# %%
cm
# Out:
# array([[298,  72],
#        [ 54,  17]], dtype=int64)

# %%
sb.heatmap(cm,annot=True,cmap="Blues") #Heat map of confusion matrix

# %%
print(classification_report(y_test,y_pred)) #Printing the classification report
# Out:
#              precision    recall  f1-score   support
#
#          No       0.85      0.81      0.83       370
#         Yes       0.19      0.24      0.21        71
#
# avg / total       0.74      0.71      0.73       441

# %%
accuracy_score(y_test,y_pred)  #Checking the accuracy of our model
# Out:
# 0.7142857142857143

# %% [markdown]
# GRADIENT BOOSTING CLASSIFIER

# %%
from sklearn.ensemble import GradientBoostingClassifier

# %%
XGB = GradientBoostingClassifier(max_depth=5,n_estimators=500,learning_rate=0.01)

# %% [markdown]
# Kept the learning rate to be low to avoid huge errors and increased the number of estimators and keeping the depth above 6 will cause the model to overfit.

# %%
XGB.fit(x_train,y_train)
# Out:
# GradientBoostingClassifier(criterion='friedman_mse', init=None,
#               learning_rate=0.01, loss='deviance', max_depth=5,
#               max_features=None, max_leaf_nodes=None,
#               min_impurity_decrease=0.0, min_impurity_split=None,
#               min_samples_leaf=1, min_samples_split=2,
#               min_weight_fraction_leaf=0.0, n_estimators=500,
#               presort='auto', random_state=None, subsample=1.0, verbose=0,
#               warm_start=False)

# %%
y_pred = XGB.predict(x_test) #Predicting the values on test dataset

# %%
XBG_cm = confusion_matrix(y_test,y_pred) #calculating the confusion matrix

# %%
print(XBG_cm)
# Out:
# [[362   8]
#  [ 63   8]]

# %%
print(classification_report(y_test,y_pred)) #Printing the classification report
# Out:
#              precision    recall  f1-score   support
#
#          No       0.85      0.98      0.91       370
#         Yes       0.50      0.11      0.18        71
#
# avg / total       0.80      0.84      0.79       441

# %%
accuracy_score(y_test,y_pred) #Calculating the accuracy of model
# Out:
# 0.83900226757369611

# %%
from sklearn.neural_network import MLPClassifier #Importing the Multi Layer Percepton Model

# %%
Neural_MLP = MLPClassifier(hidden_layer_sizes=(13,23,33),max_iter=2500,learning_rate_init=0.001,momentum=0.01,solver='adam')

# %% [markdown]
# Have hyper parameter optimized the neural network.
#
# Kept the hidden layer sizer incremental increasing as we move to the next layer.
#
# Maximum iterations have kept it 2500 so as the model has enough iterations to learn.
#
# Kept the learning rate and momentum both small as it will reduce the errors.
#
# The method is adam which is a optimization method and is a mix of adaptive gradient descent and Root Mean Square Propogation.

# %%
Neural_MLP.fit(x_train,y_train) #Fitting the Model
# Out:
# MLPClassifier(activation='relu', alpha=0.0001, batch_size='auto', beta_1=0.9,
#        beta_2=0.999, early_stopping=False, epsilon=1e-08,
#        hidden_layer_sizes=(13, 23, 33), learning_rate='constant',
#        learning_rate_init=0.001, max_iter=2500, momentum=0.01,
#        nesterovs_momentum=True, power_t=0.5, random_state=None,
#        shuffle=True, solver='adam', tol=0.0001, validation_fraction=0.1,
#        verbose=False, warm_start=False)

# %%
y_pred = Neural_MLP.predict(x_test) #Predicting on Test DataSet

# %%
MLP_NN_cm = confusion_matrix(y_test,y_pred) #Confusion Matrix

# %%
MLP_NN_cm
# Out:
# array([[368,   2],
#        [ 68,   3]], dtype=int64)

# %%
print(classification_report(y_test,y_pred))
# Out:
#              precision    recall  f1-score   support
#
#          No       0.84      0.99      0.91       370
#         Yes       0.60      0.04      0.08        71
#
# avg / total       0.80      0.84      0.78       441

# %%
accuracy_score(y_test,y_pred) #Calculating the accuracy of model
# Out:
# 0.84126984126984128

# %% [markdown]
# CONCLUSION:
#
# 1) SVM -- 0.71 -- 71%
#
#
# 2) XGB -- 0.82 -- 82%
#
#
# 3) NN -- 0.84  -- 84%
#
#
# We can conclude that Neural Network is the best model!!

# %% [markdown]
# Refernces ;
#
# https://github.com/Prashanth261993/IBM-Attrition/blob/master/RF_GBM.py
